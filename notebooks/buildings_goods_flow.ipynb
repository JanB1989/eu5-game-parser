# %% [markdown]
# # EU5 Buildings Goods Flow
#
# Loads vanilla building data from the configured EU5 install and shows the first graph tables.

# %%
from eu5gameparser import ParserConfig, load_building_data

data = load_building_data(ParserConfig.from_env())
data.buildings.head()

# %%
data.goods_flow_nodes.head(), data.goods_flow_edges.head()
